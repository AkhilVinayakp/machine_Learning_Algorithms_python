# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../Data/stud.csv")

# %%
data.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch
# 0  female        group B           bachelor's degree      standard  \
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data['parental_level_of_education'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='parental_level_of_education'>

# %%
# setting the seaborn styling
sns.set()

# %%
data['parental_level_of_education'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='parental_level_of_education'>

# %%
df_info = data['parental_level_of_education'].value_counts().reset_index()

# %%
type(df_info)
# Out:
# pandas.core.frame.DataFrame

# %%
df_info
# Out:
#   parental_level_of_education  count
# 0                some college    226
# 1          associate's degree    222
# 2                 high school    196
# 3            some high school    179
# 4           bachelor's degree    118
# 5             master's degree     59

# %%
# controlling the concepts
plt.figure(figsize=(8,6))
plt.bar(x= df_info['parental_level_of_education'], height=df_info['count'], color="midnightblue")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # stacked Area charts

# %% [markdown]
# ## Histogram

# %%
sns.set_style("white")
plt.figure(figsize=(8,6))
plt.hist(x=data['math_score'],bins=10, color="#427D9D")
plt.title("Math score distribution",fontsize=14,weight="bold")
plt.xlabel("Math score")
sns.despine()
plt.show()

# %%
sns.set_style("white")
plt.figure(figsize=(8,6))
plt.hist(x=data['writing_score'],bins=10, color="#427D9D")
plt.title("Math score distribution",fontsize=14,weight="bold")
plt.xlabel("Math score")
sns.despine()
plt.show()

# %% [markdown]
# # Categorical plots

# %% [markdown]
# - `catplots` in seaborn
#     - kind box
#     - kind

# %%
data.head()
# Out:
#    gender race_ethnicity parental_level_of_education         lunch
# 0  female        group B           bachelor's degree      standard  \
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
sns.catplot(x="parental_level_of_education", y="math_score", data=data, kind='box')
plt.xticks(rotation=90)
plt.show()

# %%
sns.catplot(x="parental_level_of_education", y="math_score", data=data, kind='swarm')
plt.xticks(rotation=90)
plt.show()
# Out:
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 21.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 13.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 8.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 31.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 20.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 23.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\nirva\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3544: UserWarning: 16.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
