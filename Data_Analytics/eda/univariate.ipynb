# %%
# steps involved in univariate analysis, and understandings

# %%
from utils.dataparser import DataOps
data = DataOps(path="F:\dataset\marketing_data.csv")
data_transformed = data.clean_data()
# Out:
# data type of the given object
# Income field type casted.

# %%
# univariate
# discrete data
d_df = data_transformed.select_dtypes(include=['object'])
con_df = data_transformed.select_dtypes(include=['int64', 'float64'])

# %%
d_df
# Out:
#        Education Marital_Status Dt_Customer Country
# 0     Graduation       Divorced     6/16/14      SP
# 1     Graduation         Single     6/15/14      CA
# 2     Graduation        Married     5/13/14      US
# 3     Graduation       Together     5/11/14     AUS
# 4     Graduation         Single      4/8/14      SP
# ...          ...            ...         ...     ...
# 2235         PhD       Divorced      3/7/13      US
# 2236    2n Cycle        Married     1/22/13      SP
# 2237  Graduation       Divorced     12/3/12      SP
# 2238  Graduation        Married    11/29/12     IND
# 2239         PhD        Married      9/1/12      CA
#
# [2240 rows x 4 columns]

# %%
con_df
# Out:
#          ID  Year_Birth   Income  Kidhome  Teenhome  Recency  MntWines
# 0      1826        1970  84835.0        0         0        0       189  \
# 1         1        1961  57091.0        0         0        0       464
# 2     10476        1958  67267.0        0         1        0       134
# 3      1386        1967  32474.0        1         1        0        10
# 4      5371        1989  21474.0        1         0        0         6
# ...     ...         ...      ...      ...       ...      ...       ...
# 2235  10142        1976  66476.0        0         1       99       372
# 2236   5263        1977  31056.0        1         0       99         5
# 2237     22        1976  46310.0        1         0       99       185
# 2238    528        1978  65819.0        0         0       99       267
# 2239   4070        1969  94871.0        0         2       99       169
#
#       MntFruits  MntMeatProducts  MntFishProducts  ...  NumCatalogPurchases
# ...

# %%
# use both visual and non visual together. 
# for discrete analysis we focus on ['count', 'nunique', 'unique'] and value counts.

# %%
data_transformed.describe().T
# Out:
#                       count          mean           std     min       25%
# ID                   2240.0   5592.159821   3246.662198     0.0   2828.25  \
# Year_Birth           2240.0   1968.805804     11.984069  1893.0   1959.00
# Income               2216.0  52247.251354  25173.076661  1730.0  35303.00
# Kidhome              2240.0      0.444196      0.538398     0.0      0.00
# Teenhome             2240.0      0.506250      0.544538     0.0      0.00
# Recency              2240.0     49.109375     28.962453     0.0     24.00
# MntWines             2240.0    303.935714    336.597393     0.0     23.75
# MntFruits            2240.0     26.302232     39.773434     0.0      1.00
# MntMeatProducts      2240.0    166.950000    225.715373     0.0     16.00
# MntFishProducts      2240.0     37.525446     54.628979     0.0      3.00
# MntSweetProducts     2240.0     27.062946     41.280498     0.0      1.00
# MntGoldProds         2240.0     44.021875     52.167439     0.0      9.00
# ...

# %% [markdown]
# What does it tells.
# - ID we can ignore
# - Year-Birth
#     The data focus on the 1893 to 1996. only answers the specific time range.
#     Need to get understanding whether we have enough data from each year. missing or not
# - Income:
#     we have missing values. ? handling it.
#     high std, and max is way over than 75% of the data . outlier ? how to handle.
# - Kidhome/Teenhome.
#     Most households have no or one child or teenager at home, with very few having two.
#
#
# - MntWines/ MntFruits
# - MntFishProducts/ MntMeatProducts
# - MntGoldProds/ MntSweetProducts
#     - +ve skewness of data, very few with high amount
#
# - NumDealsPurchases/ NumWebPurchases
#     - we have outliers.

# %%
data_transformed.describe(include=['object']).T
# Out:
#                count unique         top  freq
# Education       2240      5  Graduation  1127
# Marital_Status  2240      8     Married   864
# Dt_Customer     2240    663     8/31/12    12
# Country         2240      8          SP  1095

# %%
# Visual analysis.

# %%
# Visual analysis for univariate
#

# %%
# box plots to understand the data
ax = data_transformed['Income'].plot(kind="box")
ax.set_ylabel("Income in dollers")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# what are all useful tools
# - Boxplot
# - frequency Table
# -  Histogram
# density plots

# %%
import pandas as pd

# %%
d_df
# Out:
#        Education Marital_Status Dt_Customer Country
# 0     Graduation       Divorced     6/16/14      SP
# 1     Graduation         Single     6/15/14      CA
# 2     Graduation        Married     5/13/14      US
# 3     Graduation       Together     5/11/14     AUS
# 4     Graduation         Single      4/8/14      SP
# ...          ...            ...         ...     ...
# 2235         PhD       Divorced      3/7/13      US
# 2236    2n Cycle        Married     1/22/13      SP
# 2237  Graduation       Divorced     12/3/12      SP
# 2238  Graduation        Married    11/29/12     IND
# 2239         PhD        Married      9/1/12      CA
#
# [2240 rows x 4 columns]

# %%
import seaborn as sns

# %%
sns.countplot(data=d_df, x="Education")
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
sns.countplot(data=d_df, x="Marital_Status")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(data=d_df, x="Country")
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
con_df
# Out:
#          ID  Year_Birth   Income  Kidhome  Teenhome  Recency  MntWines
# 0      1826        1970  84835.0        0         0        0       189  \
# 1         1        1961  57091.0        0         0        0       464
# 2     10476        1958  67267.0        0         1        0       134
# 3      1386        1967  32474.0        1         1        0        10
# 4      5371        1989  21474.0        1         0        0         6
# ...     ...         ...      ...      ...       ...      ...       ...
# 2235  10142        1976  66476.0        0         1       99       372
# 2236   5263        1977  31056.0        1         0       99         5
# 2237     22        1976  46310.0        1         0       99       185
# 2238    528        1978  65819.0        0         0       99       267
# 2239   4070        1969  94871.0        0         2       99       169
#
#       MntFruits  MntMeatProducts  MntFishProducts  ...  NumCatalogPurchases
# ...

# %%
sns.displot(con_df, x="Income", kind="kde", )

# %%
con_df['Teenhome'].value_counts().__len__() > 20

con_variables = []
for column
# Out:
# False
