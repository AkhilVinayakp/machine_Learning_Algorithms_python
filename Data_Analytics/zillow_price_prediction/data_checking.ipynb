# %%
# imports 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# configs
pd.options.display.max_columns = 1000

# %%
# reading the data.

# %%
train_16 = pd.read_csv("../Data/zillow/train_2016_v2.csv")

# %%
train_16.head()
# Out:
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %%
train_16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90275 entries, 0 to 90274
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   parcelid         90275 non-null  int64
#  1   logerror         90275 non-null  float64
#  2   transactiondate  90275 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.1+ MB

# %%
# transactiondate in the form of object, converting as datetime
train_16['transactiondate'] = pd.to_datetime(train_16['transactiondate'])

# %%
train_16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90275 entries, 0 to 90274
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   parcelid         90275 non-null  int64
#  1   logerror         90275 non-null  float64
#  2   transactiondate  90275 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 2.1 MB

# %%
# target column is logerror.
train_16['logerror'].describe()
# Out:
# count    90275.000000
# mean         0.011457
# std          0.161079
# min         -4.605000
# 25%         -0.025300
# 50%          0.006000
# 75%          0.039200
# max          4.737000
# Name: logerror, dtype: float64

# %%
# there is large difference b/w mean and median. plotting histogram
plt.figure(figsize=(12,8))
sns.displot(train_16.logerror.values, bins=50, kde=True, )
plt.xlabel('logerror', fontsize=12)
plt.show()

# %%
sns.histplot(train_df["logerror"], kde=True)
# Out:
# <Axes: xlabel='logerror', ylabel='Count'>

# %%
train_df = train_16

# %%
plt.figure(figsize=(8,6))
plt.scatter(range(train_df.shape[0]), np.sort(train_df.logerror.values))
plt.xlabel('index', fontsize=12)
plt.ylabel('logerror', fontsize=12)
plt.show()

# %%
train_df['logerror'].mean()
# Out:
# 0.011457219606757128

# %%
train_df['logerror'].median()
# Out:
# 0.006

# %%
from scipy.stats import trim_mean

# %%
trim_mean(train_df['logerror'], proportiontocut=0.1)
# Out:
# 0.006604393458966229

# %%
# so there are outliers in the logerror.
# plotting a box plot.

# %%
# properties dataset.

# %%
df = pd.read_csv("../Data/zillow/properties_2016.csv")
# Out:
# C:\Users\nirva\AppData\Local\Temp\ipykernel_2804\1330877272.py:1: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../Data/zillow/properties_2016.csv")

# %%
df.shape
# Out:
# (2985217, 58)

# %%
df.head()
# Out:
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft
# 0  10754147                    NaN                       NaN           NaN  \
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid
# 0          0.0         0.0                  NaN                    NaN  \
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
#    calculatedbathnbr  decktypeid  finishedfloor1squarefeet
# ...

# %%
df.describe()
# Out:
#            parcelid  airconditioningtypeid  architecturalstyletypeid
# count  2.985217e+06          811519.000000               6061.000000  \
# mean   1.332586e+07               1.931166                  7.202607
# std    7.909966e+06               3.148587                  2.436290
# min    1.071172e+07               1.000000                  2.000000
# 25%    1.164371e+07               1.000000                  7.000000
# 50%    1.254509e+07               1.000000                  7.000000
# 75%    1.409712e+07               1.000000                  7.000000
# max    1.696019e+08              13.000000                 27.000000
#
#        basementsqft   bathroomcnt    bedroomcnt  buildingclasstypeid
# count   1628.000000  2.973755e+06  2.973767e+06         12629.000000  \
# mean     646.883292  2.209143e+00  3.088949e+00             3.725948
# std      538.793473  1.077754e+00  1.275859e+00             0.501700
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2985217 entries, 0 to 2985216
# Data columns (total 58 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   parcelid                      int64
#  1   airconditioningtypeid         float64
#  2   architecturalstyletypeid      float64
#  3   basementsqft                  float64
#  4   bathroomcnt                   float64
#  5   bedroomcnt                    float64
#  6   buildingclasstypeid           float64
#  7   buildingqualitytypeid         float64
#  8   calculatedbathnbr             float64
#  9   decktypeid                    float64
#  10  finishedfloor1squarefeet      float64
#  11  calculatedfinishedsquarefeet  float64
#  12  finishedsquarefeet12          float64
#  13  finishedsquarefeet13          float64
#  14  finishedsquarefeet15          float64
#  15  finishedsquarefeet50          float64
#  16  finishedsquarefeet6           float64
# ...

# %%
df['basementsqft'].describe()
# Out:
# count    1628.000000
# mean      646.883292
# std       538.793473
# min        20.000000
# 25%       272.000000
# 50%       534.000000
# 75%       847.250000
# max      8516.000000
# Name: basementsqft, dtype: float64

# %%
sns.histplot(df['basementsqft'], kde=True, bins=30)
# Out:
# <Axes: xlabel='basementsqft', ylabel='Count'>

# %%
# we have outliers.
