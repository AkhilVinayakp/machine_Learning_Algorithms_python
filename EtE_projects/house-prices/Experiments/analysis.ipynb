# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %%
# configuration
plt.style.use("ggplot")

# %%
df = pd.read_csv("../data/train.csv")

# %%
# basic data understanding

# %%
df.shape
# Out:
# (1460, 81)

# %%
# for seeing every column we are using 
pd.set_option('display.max_columns', 100)

# %%
df.head(20)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg  \
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
# 11  12          60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000  \
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  \
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
# data cleaning

# %%
# no id needed
# 'MSSubClass' => should be categorical 
# MSZoning => Zone area type

# %%
fld_df = df[[
       'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
       'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
       'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
       'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
       'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
       'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
       'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
       'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
       'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
       'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
       'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
       'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
       'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition', 'SalePrice'
]]

# %%
df[['MSZoning']].head(12)
# Out:
#    MSZoning
# 0        RL
# 1        RL
# 2        RL
# 3        RL
# 4        RL
# 5        RL
# 6        RL
# 7        RL
# 8        RM
# 9        RL
# 10       RL
# 11       RL

# %%
# target data explorations
# here the target value is SalePrice

# %%
df['SalePrice'].head(10)
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# 5    143000
# 6    307000
# 7    200000
# 8    129900
# 9    118000
# Name: SalePrice, dtype: int64

# %%
df['SalePrice'].sample(10)
# Out:
# 672     165000
# 336     377426
# 1122    112000
# 1010    135000
# 363     118000
# 779     135000
# 18      159000
# 103     198900
# 725     120500
# 1229    127000
# Name: SalePrice, dtype: int64

# %%
df['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
df['SalePrice'].hist(bins=50, density=True)
# Out:
# <Axes: >

# %%
# the value is continuous and right skewed.
# ? what to do with skewed data 
#   - apply log transformation to check the distribution

# %%
np.log(df['SalePrice']).hist(bins=50, density=True)
# Out:
# <Axes: >

# %%
# - applying log transformation make data more normal
# predict the log transformed of the price.

# %% [markdown]
# ### Exploring what kind of data we have

# %%
types_ = df.dtypes.to_numpy()

# %%
np.unique(df.dtypes.to_numpy())
# Out:
# array([dtype('int64'), dtype('float64'), dtype('O')], dtype=object)

# %%
np.unique(df.dtypes.to_numpy(), return_counts=True)
# Out:
# (array([dtype('int64'), dtype('float64'), dtype('O')], dtype=object),
#  array([35,  3, 43], dtype=int64))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# making MSSubClass as categorical
df['MSSubClass'] = df['MSSubClass'].astype('O')

# %%
df.drop("Id", axis=1,inplace=True)

# %%
# finding categorical values
cat_cols = [col for col in df.columns if df[col].dtype == 'O']

# %%
cat_cols
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
len(cat_cols)
# Out:
# 44

# %%
# Same for the numberical variable

# %%
numeric_cols = df.select_dtypes(include=np.number).columns.to_list()
numeric_cols.remove("SalePrice")

target_col = "SalePrice"

# %%
numeric_cols.__len__()
# Out:
# 35

# %%
numeric_cols
# Out:
# ['LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
# Missing values

# %%
df.isnull().sum().sum()
# Out:
# 7829

# %%
round(df.isnull().mean() * 100, 2)
# Out:
# MSSubClass        0.00
# MSZoning          0.00
# LotFrontage      17.74
# LotArea           0.00
# Street            0.00
#                  ...
# MoSold            0.00
# YrSold            0.00
# SaleType          0.00
# SaleCondition     0.00
# SalePrice         0.00
# Length: 80, dtype: float64

# %%
# importing custom modules
import os
import sys
# for custom python file
from importlib import reload

# %%
#setting up the path 
module_path = os.path.abspath(os.path.join("../.."))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from utils import field_analyser as fal

# %%
reload(fal)
# Out:
# <module 'utils.field_analyser' from 'c:\\Users\\nirva\\Documents\\GitHub\\machine_Learning_Algorithms_python\\EtE_projects\\utils\\field_analyser.py'>

# %%
fal.missing_stats(df).T
# Out:
# total missing fields count:  19
# Total values missing:  7829
#                      PoolQC  MiscFeature    Alley    Fence  MasVnrType
# Missing Values      1453.00       1406.0  1369.00  1179.00      872.00  \
# Missing Percentage    99.52         96.3    93.77    80.75       59.73
#
#                     FireplaceQu  LotFrontage  GarageYrBlt  GarageCond
# Missing Values           690.00       259.00        81.00       81.00  \
# Missing Percentage        47.26        17.74         5.55        5.55
#
#                     GarageType  GarageFinish  GarageQual  BsmtExposure
# Missing Values           81.00         81.00       81.00          38.0  \
# Missing Percentage        5.55          5.55        5.55           2.6
#
#                     BsmtFinType2  BsmtCond  BsmtQual  BsmtFinType1
# Missing Values              38.0     37.00     37.00         37.00  \
# Missing Percentage           2.6      2.53      2.53          2.53
#
# ...

# %%
# by code.
missing_val_cols = [col for col in df.columns if df[col].isnull().sum() > 0]

# %%
missing_val_cols.__len__()
# Out:
# 19

# %%
df[missing_val_cols].isnull().mean().sort_values(ascending=False)
# Out:
# PoolQC          0.995205
# MiscFeature     0.963014
# Alley           0.937671
# Fence           0.807534
# MasVnrType      0.597260
# FireplaceQu     0.472603
# LotFrontage     0.177397
# GarageType      0.055479
# GarageYrBlt     0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# GarageCond      0.055479
# BsmtFinType2    0.026027
# BsmtExposure    0.026027
# BsmtFinType1    0.025342
# BsmtCond        0.025342
# BsmtQual        0.025342
# MasVnrArea      0.005479
# Electrical      0.000685
# dtype: float64

# %%
df[missing_val_cols].isnull().mean().sort_values(ascending=False).plot(kind='bar', figsize=(10,6))
plt.ylabel("Missing percentage")
plt.axhline(y=0.8, color='y', linestyle='-')
plt.axhline(y=0.9, color='g', linestyle='-')

# %% [markdown]
# ### How we can find fix missing values
# - separating the missing value cols into categorical and numerical

# %%
numeric_na_cols = [col for col in missing_val_cols if col in numeric_cols]
cat_na_cols = [col for col in missing_val_cols if col in cat_cols]

# %%
print(f"In categorical we have {len(cat_na_cols)} missing values")
print(f"In numeric we have {len(numeric_na_cols)} missing values")
# Out:
# In categorical we have 16 missing values
# In numeric we have 3 missing values

# %%
# analyzing the relation ship with target value

# %%
reload(fal)
# Out:
# <module 'utils.field_analyser' from 'c:\\Users\\nirva\\Documents\\GitHub\\machine_Learning_Algorithms_python\\EtE_projects\\utils\\field_analyser.py'>

# %%
fal.target_analyser_with_na_fields(df, "PoolQC")

# %%
for col in missing_val_cols:
    fal.target_analyser_with_na_fields(df, col)

# %%
# shows what is the sale price when the value is missing and what it is when it is not missing.

# %% [markdown]
# ### numeric variable analysis

# %%
numeric_cols
# Out:
# ['LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %%
# now we have below temporal values
# - YearBuilt
# - YearRemodAdd
# - GarageYrBlt
# - YrSold

# %%
year_cols = ["YearBuilt", "YearRemodAdd", "GarageYrBlt","YrSold"]

# %%
for ycol in year_cols:
    print(f"unique value in the {ycol}")
    print(df[ycol].unique())
# Out:
# unique value in the YearBuilt
# [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# unique value in the YearRemodAdd
# [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...

# %%
df.groupby("YrSold")['SalePrice'].median().plot(kind='line')
plt.ylabel("SalePrice")
# Out:
# Text(0, 0.5, 'SalePrice')

# %%
# ? why the trend is decreasing when the Yrsold increases

# %%
df.groupby("YearBuilt")["SalePrice"].median().plot()
plt.ylabel("Median of Sale Price")
# Out:
# Text(0, 0.5, 'Median of Sale Price')

# %%
# As the year sold increases Sale price decreases
# As the Year build increase Sale price also increase
# calculate the age of the house and what is the pattern of price
# th age can be calculated from the Year build Year of renovation basically any other in temporal group

# %%
df['age from sold'] = df['YrSold'] - df['YearBuilt']
df_temp = df.groupby("YrSold")[['YrSold', 'age from sold', 'SalePrice']].median()

# %%
df_temp
# Out:
#         YrSold  age from sold  SalePrice
# YrSold
# 2006    2006.0           32.0   163995.0
# 2007    2007.0           32.0   167000.0
# 2008    2008.0           38.5   164000.0
# 2009    2009.0           33.0   162000.0
# 2010    2010.0           39.0   155000.0

# %%
fig, ax1 = plt.subplots()
x = df_temp['YrSold']
y1 = df_temp['SalePrice']
ax1.plot(x, y1, 'g-')
ax1.set_xlabel('Year sold')
ax1.set_ylabel('Sale Price', color='g')  # Y-axis label for the first plot
ax1.tick_params(axis='y', labelcolor='g')  # Y-axis ticks for the first plot

# Create a second set of axes sharing the same x-axis
ax2 = ax1.twinx()
y2 = df_temp['age from sold']
# Plot data on the second y-axis (right)
ax2.plot(x, y2, 'b-')
ax2.set_ylabel('Age from Sold', color='b')  # Y-axis label for the second plot
ax2.tick_params(axis='y', labelcolor='b')  # Y-axis ticks for the second plot

# Title for the entire plot
plt.title('Age vs Sale price')

# Show the plot
plt.show()

# %%
# with external

# %%
from utils import plotter as plt_gr

# %%
reload(plt_gr)
# Out:
# <module 'utils.plotter' from 'c:\\Users\\nirva\\Documents\\GitHub\\machine_Learning_Algorithms_python\\EtE_projects\\utils\\plotter.py'>

# %%
_, plot = plt_gr.plotTemporal_correlation(df=df, col_name='YearBuilt')

# %% [markdown]
# '''
# as we can see the sale price decrease happens from 2007 onwards
# the ages of houses sold from when they are build  after the year 2007 also in increase hence the trend in the sale price justifies

# %%
_, plot = plt_gr.plotTemporal_correlation(df=df, col_name='YearRemodAdd')

# %%
_, plot = plt_gr.plotTemporal_correlation(df=df, col_name='GarageYrBlt')

# %%
# the same pattern shows here also.

# %% [markdown]
# ## Numeric variable analysis

# %% [markdown]
# - Discrete variables
# - Continuous variables

# %%
# data&packages loading
# Since running small part of the notebook
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/train.csv")

# %%
pd.set_option("display.max_columns", 100)

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg  \
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm  \
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt
# ...

# %%
data['MSSubClass'].nunique()
# Out:
# 15

# %%
# choosing the discrete values : number of unique values only 20 , how come up with the value 20 ?
# we also need to exclude the year cols
# 
year_cols = ["YearBuilt", "YearRemodAdd", "GarageYrBlt","YrSold"]
data.drop("Id", axis=1, inplace=True)
numeric_cols = data.select_dtypes(include=np.number).columns.to_list()
numeric_cols.remove("SalePrice")
descrete_cols = [col for col in numeric_cols if data[col].nunique() < 20 and col not in year_cols]

# %%
descrete_cols.__len__()
# Out:
# 14

# %%
descrete_cols
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  'PoolArea',
#  'MoSold']

# %%
data[descrete_cols].head()
# Out:
#    MSSubClass  OverallQual  OverallCond  BsmtFullBath  BsmtHalfBath  FullBath
# 0          60            7            5             1             0         2  \
# 1          20            6            8             0             1         2
# 2          60            7            5             1             0         2
# 3          70            7            5             1             0         1
# 4          60            8            5             1             0         2
#
#    HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars
# 0         1             3             1             8           0           2  \
# 1         0             3             1             6           1           2
# 2         1             3             1             6           1           2
# 3         0             3             1             7           1           3
# 4         1             4             1             9           1           3
#
#    PoolArea  MoSold
# ...

# %%
data[descrete_cols].sample(10)
# Out:
#       MSSubClass  OverallQual  OverallCond  BsmtFullBath  BsmtHalfBath
# 731           80            7            5             1             0  \
# 512           20            5            5             1             0
# 498           20            5            7             0             0
# 1405         120            8            5             1             1
# 934           20            7            7             1             0
# 809           75            5            5             0             0
# 391           60            6            5             1             0
# 680          120            6            5             0             0
# 871           60            6            5             0             0
# 648           60            6            5             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd
# 731          2         0             3             1             6  \
# ...

# %%
# analysis of effect of the categories and sale price

# %%
# importing custom function
import os
import sys
from importlib import reload

# %%
module_path = os.path.abspath(os.path.join("../.."))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from utils import plotter

# %%
reload(plotter)
# Out:
# <module 'utils.plotter' from 'c:\\Users\\nirva\\Documents\\GitHub\\machine_Learning_Algorithms_python\\EtE_projects\\utils\\plotter.py'>

# %%
for var in descrete_cols:
    # make boxplot with Catplot
    sns.catplot(x=var, y='SalePrice', data=data, kind="box", height=4, aspect=1.5)
    # add data points to boxplot with stripplot
    sns.stripplot(x=var, y='SalePrice', data=data, jitter=0.1, alpha=0.3, color='k')
    plt.show()

# %%
# continuous variable
continuos_cols = [col for col in numeric_cols if col not in descrete_cols+year_cols]

# %%
continuos_cols.__len__()
# Out:
# 18

# %%
data[continuos_cols].head()
# Out:
#    LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF
# 0         65.0     8450       196.0         706           0        150  \
# 1         80.0     9600         0.0         978           0        284
# 2         68.0    11250       162.0         486           0        434
# 3         60.0     9550         0.0         216           0        540
# 4         84.0    14260       350.0         655           0        490
#
#    TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  GarageArea
# 0          856       856       854             0       1710         548  \
# 1         1262      1262         0             0       1262         460
# 2          920       920       866             0       1786         608
# 3          756       961       756             0       1717         642
# 4         1145      1145      1053             0       2198         836
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  MiscVal
# ...

# %%
data[continuos_cols].hist(bins=26, figsize=(10,10))
plt.tight_layout()
plt.show()

# %%
reload(plotter)
# Out:
# <module 'utils.plotter' from 'c:\\Users\\nirva\\Documents\\GitHub\\machine_Learning_Algorithms_python\\EtE_projects\\utils\\plotter.py'>

# %%
plotter.plot_field(data, "LotArea")

# %%
plotter.plot_field(data, "LotFrontage")

# %%
# there are highly skewed data in continuos cols
# check for log transformation
